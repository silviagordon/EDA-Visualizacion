# %% [markdown]
# ### NOMBRE EQUIPO/EMPRESA: PYTHONISAS.SL

# %% [markdown]
# ### PDF KAGGLE:
#
# Preguntas principales: Q2 (género) y Q5 (posición professional)
#
# Preguntas rama: Q20 (sector), Q24 (actividades) y Q42 (recursos-datos)

# %%
with open("Datos/data_txt_clean.txt") as f:
    txt = f.readlines()

# %%
txt[7]
# Out:
# '6;India;Some college/university study without earning a bachelor’s degree;Student;1-3 years;Python;A laptop;Never;< 1 year;null;null;null;null;null;null;null;null;null; C++, Java, Javascript;Visual Studio ,Visual Studio Code (VSCode) ,Jupyter Notebook; None;Geoplotlib ;Fast.ai ;null;null;null;null\n'

# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
txt_csv= pd.read_csv("Datos/data_txt_clean.txt", sep=";")
txt_csv.head(2)
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
#
#        Q8                                                Q11        Q13  \
# 0  Python                                           A laptop  2-5 times
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#           Q15                        Q20                   Q21  Q22  \
# 0  5-10 years  Manufacturing/Fabrication      50-249 employees  3-4
# 1    < 1 year  Manufacturing/Fabrication  1000-9,999 employees  1-2
#
#                                                  Q23            Q25  \
# 0                      No (we do not use ML methods)  25,000-29,999
# 1  We are exploring ML methods (and may one day p...  60,000-69,999
#
#          Q26  Q33  Q35                                                Q41  \
# ...

# %%
txt_csv_preguntas = txt_csv.rename(columns = {"Q5":"Puesto", "Q20":"Sector","Q24":"Actividades"})
txt_csv_preguntas.head(2)
# Out:
#    index         Q3                 Q4                   Puesto          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
#
#        Q8                                                Q11        Q13  \
# 0  Python                                           A laptop  2-5 times
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#           Q15                     Sector                   Q21  Q22  \
# 0  5-10 years  Manufacturing/Fabrication      50-249 employees  3-4
# 1    < 1 year  Manufacturing/Fabrication  1000-9,999 employees  1-2
#
#                                                  Q23            Q25  \
# 0                      No (we do not use ML methods)  25,000-29,999
# 1  We are exploring ML methods (and may one day p...  60,000-69,999
#
#          Q26  Q33  Q35                                                Q41  \
# ...

# %%
txt_csv_preguntas2 = pd.DataFrame(txt_csv_preguntas["Sector"])
txt_csv_preguntas2.head()
# Out:
#                       Sector
# 0  Manufacturing/Fabrication
# 1  Manufacturing/Fabrication
# 2        Academics/Education
# 3        Academics/Education
# 4        Academics/Education

# %%
txt_csv_preguntas3 = pd.DataFrame(txt_csv_preguntas["Puesto"])
txt_csv_preguntas3.head()
# Out:
#                     Puesto
# 0                    Other
# 1  Program/Project Manager
# 2        Software Engineer
# 3       Research Scientist
# 4                    Other

# %%
txt_csv_preguntas4 = pd.DataFrame(txt_csv_preguntas["Actividades"])
txt_csv_preguntas4.head()
# Out:
#                                          Actividades
# 0   None of these activities are an important par...
# 1   Build and/or run the data infrastructure that...
# 2   None of these activities are an important par...
# 3   Do research that advances the state of the ar...
# 4  Analyze and understand data to influence produ...

# %%
csv2 = pd.read_csv("Datos/exported_db_data.csv")
csv2.head()
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10  \
# 0        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN
#
#             Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15  \
# ...

# %%
csv = pd.read_csv("Datos/data_remaning_kaggle.csv")
csv.head()
# Out:
#    Unnamed: 0  index                                         Q18_Part_1  \
# 0           0      0  General purpose image/video tools (PIL, cv2, s...
# 1           1      1                                                NaN
# 2           2      2                                                NaN
# 3           3      3  General purpose image/video tools (PIL, cv2, s...
# 4           4      4                                                NaN
#
#                                           Q18_Part_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Image segmentation methods (U-Net, Mask R-CNN,...
# 4                                                NaN
#
#                                           Q18_Part_3  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
import re
import os
import xml.etree.ElementTree as ET
import mysql.connector 
import pandas as pd

# %%
def lectura_xml(ruta):
    

    tree = ET.parse(ruta)
    root = tree.getroot()

    xml_lista = []
    for child in root:
        xml_dict = {}
        for subchild in child:
            xml_dict[subchild.tag] = subchild.text
            xml_lista.append(xml_dict) # Es una lista que contiene diccionarios
        return xml_lista

# %%
lectura_xml("Datos/data_xml_clean.xml")
# Out:
# [{'level_0': '0',
#   'index': '0',
#   'time': '910',
#   'age': '50-54',
#   'gender': 'Man'},
#  {'level_0': '0',
#   'index': '0',
#   'time': '910',
#   'age': '50-54',
#   'gender': 'Man'},
#  {'level_0': '0',
#   'index': '0',
#   'time': '910',
#   'age': '50-54',
#   'gender': 'Man'},
#  {'level_0': '0',
#   'index': '0',
#   'time': '910',
#   'age': '50-54',
#   'gender': 'Man'},
#  {'level_0': '0',
#   'index': '0',
#   'time': '910',
#   'age': '50-54',
#   'gender': 'Man'}]

# %% [markdown]
# CONOCEMOS LA INFORMACIÓN PRINCIPAL DEL CSV EXPORTED_DB

# %%
csv2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        25973 non-null  int64
#  1   Q10_Part_1   9507 non-null   object
#  2   Q10_Part_2   9792 non-null   object
#  3   Q10_Part_3   1062 non-null   object
#  4   Q10_Part_4   209 non-null    object
#  5   Q10_Part_5   1770 non-null   object
#  6   Q10_Part_6   175 non-null    object
#  7   Q10_Part_7   1067 non-null   object
#  8   Q10_Part_8   753 non-null    object
#  9   Q10_Part_9   348 non-null    object
#  10  Q10_Part_10  2051 non-null   object
#  11  Q10_Part_11  1794 non-null   object
#  12  Q10_Part_12  590 non-null    object
#  13  Q10_Part_13  251 non-null    object
#  14  Q10_Part_14  260 non-null    object
#  15  Q10_Part_15  147 non-null    object
#  16  Q10_Part_16  7174 non-null   object
#  17  Q10_OTHER    737 non-null    object
# ...

# %%
csv2.describe()
# Out:
#               index
# count  25973.000000
# mean   12986.000000
# std     7497.903607
# min        0.000000
# 25%     6493.000000
# 50%    12986.000000
# 75%    19479.000000
# max    25972.000000
